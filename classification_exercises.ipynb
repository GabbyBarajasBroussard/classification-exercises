# %% [markdown]
# # Acquire Data

# %% [markdown]
# ## #1.

# %% [markdown]
# ### In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data.

# %%
from math import sqrt
from scipy import stats

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pydataset import data

# %% [markdown]
# <li> Create a pandas dataframe, df_iris, from this data.

# %%
df_iris= data('iris')

# %% [markdown]
# <li>print the first 3 rows

# %%
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# <li>print the number of rows and columns (shape)

# %%
df_iris.shape
# Out:
# (150, 5)

# %% [markdown]
# <li>print the column names

# %%
list(df_iris.columns)
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %% [markdown]
# <li>print the data type of each column

# %%
list(df_iris.dtypes)
# Out:
# [dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O')]

# %% [markdown]
# <li>print the summary statistics for each of the numeric variables. Would you recommend rescaling the data based on these statistics?

# %%
df_iris._get_numeric_data().describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# Sepal.Length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# Sepal.Width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# Petal.Length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# Petal.Width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# # #2.

# %% [markdown]
# <li>Read the Table1_CustDetails table from the Excel_Exercises.xlsx file into a dataframe named df_excel.

# %%
df_excel = pd.read_excel("Spreadsheets_Exercises.xlsx")

# %% [markdown]
# <li>assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample= df_excel.head(100)
df_excel_sample
# Out:
#    customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0   0002-ORFBO  Female                  0     Yes        Yes              1
# 1   0003-MKNFE    Male                  0      No         No              2
# 2   0004-TLHLJ    Male                  0      No         No              1
# 3   0011-IGKFF    Male                  1     Yes         No              1
# 4   0013-EXCHZ  Female                  1     Yes         No              1
# 5   0013-MHZWF  Female                  0      No        Yes              1
# 6   0013-SMEOE  Female                  1     Yes         No              1
# 7   0014-BMAQU    Male                  0     Yes         No              2
# 8   0015-UOCOJ  Female                  1      No         No              1
# 9   0016-QLJIS  Female                  0     Yes        Yes              2
# 10  0017-DINOC    Male                  0      No         No              0
# ...

# %% [markdown]
# <li>print the number of rows of your original dataframe

# %%
len(df_excel.index)
# Out:
# 7049

# %% [markdown]
# <li>print the first 5 column names

# %%
list(df_excel.columns[0:5])
# Out:
# ['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents']

# %% [markdown]
# <li>print the column names that have a data type of object

# %%
object_columns= df_excel.dtypes[df_excel.dtypes == np.object]
list(object_columns.index)
# Out:
# ['customer_id', 'gender', 'partner', 'dependents', 'payment_type', 'churn']

# %% [markdown]
# <li>compute the range for each of the numeric variables.

# %%
num_var=df_excel._get_numeric_data().describe().T
num_var['range']= num_var['max']- num_var['min']
num_var['range']
# Out:
# is_senior_citizen       1.0
# phone_service           2.0
# internet_service        2.0
# contract_type           2.0
# monthly_charges       100.5
# total_charges        8666.0
# Name: range, dtype: float64

# %% [markdown]
# # #3.

# %% [markdown]
# <li>Read the data from this google sheet into a dataframe, df_google

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_google = pd.read_csv(csv_export_url)

# %% [markdown]
# <li>print the first 3 rows

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# <li>print the number of rows and columns

# %%
df_google.shape
# Out:
# (891, 12)

# %% [markdown]
# <li>print the column names

# %%
list(df_google.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# <li>print the data type of each column

# %%
list(df_google.dtypes)
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O')]

# %% [markdown]
# <li>print the summary statistics for each of the numeric variables

# %%
df_google._get_numeric_data().describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %% [markdown]
# <li>print the unique values for each of your categorical variables

# %%
df_google.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # Prepare Data
#
# ## Using the Iris Data:
#
# <li>Use the function defined in acquire.py to load the iris data.

# %%
import acquire

# %%
iris= acquire.get_iris_data()

# %% [markdown]
# <li>Drop the species_id and measurement_id columns.

# %%
iris.drop(columns=['species_id', 'measurement_id'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species_name
# 0             5.1          3.5           1.4          0.2       setosa
# 1             4.9          3.0           1.4          0.2       setosa
# 2             4.7          3.2           1.3          0.2       setosa
# 3             4.6          3.1           1.5          0.2       setosa
# 4             5.0          3.6           1.4          0.2       setosa
# 5             5.4          3.9           1.7          0.4       setosa
# 6             4.6          3.4           1.4          0.3       setosa
# 7             5.0          3.4           1.5          0.2       setosa
# 8             4.4          2.9           1.4          0.2       setosa
# 9             4.9          3.1           1.5          0.1       setosa
# 10            5.4          3.7           1.5          0.2       setosa
# 11            4.8          3.4           1.6          0.2       setosa
# ...

# %% [markdown]
# <li>Rename the species_name column to just species.

# %%
iris.rename(columns={"species_name": "species"})
# Out:
#      species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0             1               1           5.1          3.5           1.4
# 1             1               2           4.9          3.0           1.4
# 2             1               3           4.7          3.2           1.3
# 3             1               4           4.6          3.1           1.5
# 4             1               5           5.0          3.6           1.4
# 5             1               6           5.4          3.9           1.7
# 6             1               7           4.6          3.4           1.4
# 7             1               8           5.0          3.4           1.5
# 8             1               9           4.4          2.9           1.4
# 9             1              10           4.9          3.1           1.5
# 10            1              11           5.4          3.7           1.5
# 11            1              12           4.8          3.4           1.6
# ...

# %% [markdown]
# <li>Create dummy variables of the species name.

# %%
dummy_df = pd.get_dummies(iris[['species_name']])
dummy_df
# Out:
#      species_name_setosa  species_name_versicolor  species_name_virginica
# 0                      1                        0                       0
# 1                      1                        0                       0
# 2                      1                        0                       0
# 3                      1                        0                       0
# 4                      1                        0                       0
# 5                      1                        0                       0
# 6                      1                        0                       0
# 7                      1                        0                       0
# 8                      1                        0                       0
# 9                      1                        0                       0
# 10                     1                        0                       0
# 11                     1                        0                       0
# ...

# %% [markdown]
# <li>Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def prep_iris(iris):
    iris.drop(columns=['species_id', 'measurement_id'])
    iris.rename(columns={"species_name": "species"})
    dummy_df = pd.get_dummies(iris[['species_name']])
    iris = pd.concat([iris, dummy_df], axis=1)
    return iris

# %% [markdown]
# # Explore Data

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import prepare
from acquire import get_iris_data
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %% [markdown]
# ### #1. Split your data into train, validate, and test samples

# %%
df = acquire.get_iris_data()

# %%
iris = prepare.prep_iris(df)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  \
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
#    species_setosa  species_versicolor  species_virginica
# 0               1                   0                  0
# 1               1                   0                  0
# 2               1                   0                  0
# 3               1                   0                  0
# 4               1                   0                  0

# %%
train, test = train_test_split(iris, test_size=.3, random_state=719, stratify=iris.species)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 84 to 122
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal_length        105 non-null    float64
#  1   sepal_width         105 non-null    float64
#  2   petal_length        105 non-null    float64
#  3   petal_width         105 non-null    float64
#  4   species             105 non-null    object
#  5   species_setosa      105 non-null    uint8
#  6   species_versicolor  105 non-null    uint8
#  7   species_virginica   105 non-null    uint8
# dtypes: float64(4), object(1), uint8(3)
# memory usage: 5.2+ KB

# %% [markdown]
# ### #.2 Create a swarmplot using a melted dataframe of all your numeric variables. The x-axis should be the variable name, the y-axis the measure. Add another dimension using color to represent species. Document takeaways from this visualization.

# %%
train.drop(columns = ['species_versicolor', 'species_virginica', 'species_setosa'], inplace = True)
melted_train = train.melt(id_vars=['species'], value_name='measurements')
melted_train.head()
# Out:
#       species      variable  measurements
# 0  versicolor  sepal_length           5.4
# 1      setosa  sepal_length           4.8
# 2  versicolor  sepal_length           6.6
# 3   virginica  sepal_length           6.3
# 4  versicolor  sepal_length           5.9

# %%
sns.swarmplot(x="variable", y="measurements", hue="species",
              palette="viridis", data=melted_train)
plt.xlabel("Variable")
plt.ylabel("Measurements")
plt.title("Swarmplot of Measurement of Three Iris Species")
# Out:
# Text(0.5, 1.0, 'Swarmplot of Measurement of Three Iris Species')

# %% [markdown]
# Create 4 subplots (2 rows x 2 columns) of scatterplots.
#
# <li> sepal_length x sepal_width
# <li> petal_length x petal_width
# <li> sepal_area x petal_area
# <li> sepal_length x petal_length

# %%
plt.figure(figsize=(13,10))
plt.suptitle("Evaluating the Correlation Between Iris Species Measurements")

plt.subplot(221)
plt.scatter (train.sepal_length, train. sepal_width, color="crimson")
plt.title("Sepal Length x Sepal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")


plt.subplot(222)
plt.scatter (train.petal_length, train.petal_width, color="firebrick")
plt.title("Petal Length x Petal Width")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")


plt.subplot(223)
x = train.sepal_length * train.sepal_width
y = train.petal_length * train.petal_width
plt.title("Sepal Area x Petal Area")
plt.xlabel("Sepal Area")
plt.ylabel("Petal Area")

plt.scatter(x, y, color="firebrick")

plt.subplot(224)
plt.scatter(train.sepal_length, train.petal_length, color="crimson")
plt.title("Sepal Length x Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
plt.figure(figsize=(13,10))
plt.suptitle("Evaluating the Correlation Between Iris Species Measurements")
palette= sns.set_palette('seismic_r')
plt.subplot(221)
plt.title("Sepal Length x Sepal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
sns.scatterplot (train.sepal_length, train. sepal_width, hue=train.species)

plt.subplot(222)
plt.title("Petal Length x Petal Width")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
sns.scatterplot (train.petal_length, train.petal_width, hue=train.species)

plt.subplot(223)
x = train.sepal_length * train.sepal_width
y = train.petal_length * train.petal_width
plt.title("Sepal Area x Petal Area")
plt.xlabel("Sepal Area")
plt.ylabel("Petal Area")
sns.scatterplot(x, y, hue=train.species)

plt.subplot(224)
plt.title("Sepal Length x Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
sns.scatterplot(train.sepal_length, train.petal_length, hue=train.species)

# %% [markdown]
# <b> Takeaway: </b> The strongest correlation is betwen Petal Length and Petal Width. The second stronget correlation is between Sepal Length and Petal Length. The weakest two correlations are Sepal Area and Petal Area along with Sepal Length and Sepal Width.

# %% [markdown]
# ### #4. Create a heatmap of each variable layering correlation coefficient on top.

# %%
sns.heatmap(train.corr(), cmap="magma",center=0, annot=True)
plt.suptitle("Evaluating the Correlation Between Iris Species Measurements")
# Out:
# Text(0.5, 0.98, 'Evaluating the Correlation Between Iris Species Measurements')

# %% [markdown]
# ### #5. Create a scatter matrix visualizing the interaction of each variable.

# %%
pd.plotting.scatter_matrix(train, alpha=0.2, figsize=(15, 8))
plt.show()

# %% [markdown]
# ### #6.
# Is the sepal length significantly different in virginica compared to versicolor? Run a statistical experiment to test this.
#
# Make sure to include a null hypothesis, alternative hypothesis, results, and summary.
#
# What is your takeaway from this statistical testing?

# %% [markdown]
# $H0$: There is an insiginificant difference in sepal length between virginica and versicolor iris species. <br>
# $Ha$: There is a significant difference in sepal length between virginica and versicolor iris species. <br>
# $a$= 0.05

# %%
import scipy.stats as stats
virginica = train[train.species == 'virginica']
versicolor= train[train.species == 'versicolor']

# %%
virginica.sepal_length.var(), versicolor.sepal_length.var()
# Out:
# (0.37593277310924383, 0.27045378151260513)

# %%
alpha= 0.05
null_hypothesis = "there is an insiginificant difference in sepal length between virginica and versicolor iris species."
t, p = stats.ttest_ind(
    virginica.sepal_length,
    versicolor.sepal_length,)
print('t=', t, 'p=', p)
# Out:
# t= 5.10888461682989 p= 2.8235232810371566e-06

# %%
if p > alpha:
    print("We fail to reject the null hypothesis. The null hypothesis is that", null_hypothesis)
elif t < 0 :
    print("We fail to reject the null hypothesis. The null hypothesis is that", null_hypothesis)
else:
    print("We reject the null hypothesis. The null hypothesis is", null_hypothesis)
# Out:
# We reject the null hypothesis. The null hypothesis is there is an insiginificant difference in sepal length between virginica and versicolor iris species.

# %% [markdown]
# <b> Takeaway: </b> We rejected the null hypothesis because the p value was less than the alpha. From this we can draw that there is a significant difference in sepal length between the two iris species.

# %% [markdown]
# ### #7. Create any other visualizations and run any other statistical tests you think will be helpful in exploring this data set.

# %%
ax = sns.violinplot(x="variable", y="measurements", hue="species", 
                    data=melted_train, scale="width", palette="Set3")

# %%
g = sns.catplot(x= "variable", y="measurements",
                col="species",
                data=melted_train, kind="violin", split=True,
                height=10, aspect=.9);
